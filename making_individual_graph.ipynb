# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df =pd.read_csv("drive/My Drive/Colab Drive/ethereum_data.csv")
df
# Out:
#           Unnamed: 0                                        from  \
# 0                  0  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# 1                  1  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# 2                  2  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# 3                  3  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# 4                  4  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# ...              ...                                         ...
# 13551298    13551298  0x0f4153c9e7e34528960628d827a11d522f7641a9
# 13551299    13551299  0x0f4153c9e7e34528960628d827a11d522f7641a9
# 13551300    13551300  0x5462733634994f5f9ad258de7bd9aeb6c8caceeb
# 13551301    13551301  0x5b2757a623c829105cbcb9c626f086c60f813a8a
# 13551302    13551302  0x5b2757a623c829105cbcb9c626f086c60f813a8a
#
#                                                   to    amount     timestamp  \
# 0         0x1266f8b9e4dffc9e2f719bf51713f7e714516861  2.344623  1.526454e+09
# ...

# %%
df['date'] = pd.to_datetime(df['timestamp'], unit='s')
df['date'] = df['date'].dt.date

# %%
# Convert the "date" column to a datetime object
df['date'] = pd.to_datetime(df['date'])

# Define the date range
start_date = pd.to_datetime("2017-01-01")
end_date = pd.to_datetime("2019-01-01")

# Filter the dataset to include only transactions within the date range
filtered_df = df[(df['date'] >= start_date) & (df['date'] < end_date)]

# %%
df = filtered_df

# %%
df.shape
# Out:
# (13061004, 8)

# %%
condition = df['amount'] != 0

# Use boolean indexing to keep rows that meet the condition
df = df[condition]

# %%
p = filtered_df[(filtered_df['fromIsPhi'] == 1) | (filtered_df['toIsPhi'] == 1)]

# %%
selected_columns1 = p[["from","fromIsPhi"]]
new_df1 = selected_columns1.copy()
selected_columns2 = p[["to","toIsPhi"]]
new_df2 = selected_columns2.copy()
new_df1.rename(columns = {'from':'ID', 'fromIsPhi':'IsPhi'}, inplace = True)
new_df2.rename(columns = {'to':'ID', 'toIsPhi':'IsPhi'}, inplace = True)
dataframe = [new_df1, new_df2]
allids = pd.concat(dataframe)
uniqueids=allids.drop_duplicates()
uniqueids.IsPhi.value_counts()
# Out:
# 0    28259
# 1     1165
# Name: IsPhi, dtype: int64

# %%
isphi_list = uniqueids[uniqueids['IsPhi'] == 1]
notphi_list = uniqueids[uniqueids['IsPhi'] == 0]

# %%
notphi_to_notphi = df[df['to'].isin(notphi_list['ID']) & df['from'].isin(notphi_list['ID'])]
notphi_to_notphi
# Out:
#           Unnamed: 0                                        from  \
# 0                  0  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# 1                  1  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# 2                  2  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# 3                  3  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# 4                  4  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# ...              ...                                         ...
# 13383035    13383035  0xf935b95768168489fa9107730f3a86a19e48024f
# 13488890    13488890  0x0d8415be40925d965ade2cd62be5680389d640e4
# 13488891    13488891  0x0d8415be40925d965ade2cd62be5680389d640e4
# 13488896    13488896  0xe4edc0ee94ba28ac89d7304c72fa95081a3bef72
# 13488897    13488897  0xe4edc0ee94ba28ac89d7304c72fa95081a3bef72
#
#                                                   to    amount     timestamp  \
# 0         0x1266f8b9e4dffc9e2f719bf51713f7e714516861  2.344623  1.526454e+09
# ...

# %%
notphi_to_phi =  df[df['to'].isin(isphi_list['ID']) & df['from'].isin(notphi_list['ID'])]
notphi_to_phi
# Out:
#           Unnamed: 0                                        from  \
# 101              101  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# 102              102  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# 103              103  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# 104              104  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# 105              105  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# ...              ...                                         ...
# 13473756    13473756  0xee7ff16e72b36cce26a40e6102eed6f66a099607
# 13473757    13473757  0x8b7b0f6d86fccc2030b01934d18364b14f796286
# 13473807    13473807  0xdcf880ba3487a4e95259d79994226b1e4f8d9458
# 13487269    13487269  0x2ff58a66bf3073e4c6016e1a5d8d8eb6483f5723
# 13519892    13519892  0x7eec58c8231acda05ccf7389750628f6075e29fa
#
#                                                   to    amount     timestamp  \
# 101       0x356f1b9ac8dd5b38d3644b3696741355cda0a6e5  1.088962  1.499284e+09
# ...

# %%
phi_to_phi = df[df['to'].isin(isphi_list['ID']) & df['from'].isin(isphi_list['ID'])]
phi_to_phi
# Out:
#           Unnamed: 0                                        from  \
# 77056          77056  0x40949225c4a1745a9946f6aaf763241c082cb9ac
# 77057          77057  0x40949225c4a1745a9946f6aaf763241c082cb9ac
# 77058          77058  0x40949225c4a1745a9946f6aaf763241c082cb9ac
# 370408        370408  0x5208d7f63a089906889a5a9caed81e9c889e64f8
# 845643        845643  0x44a7ff01f7d38c73530c279e19d31527bdcf8c78
# ...              ...                                         ...
# 10108427    10108427  0xbe969917962ef564f936a3f93dd4cfb315ec41ee
# 10219262    10219262  0xc2dc7b86a5cfbc89e20d5d03026e973958d8e3b3
# 10345633    10345633  0x110d246eace2bb15a065db0d351b352dfc048b85
# 11100671    11100671  0xee83bf55194787acc44d6316623998c1876aed8a
# 11955824    11955824  0xf832a212d1c81b89e2dabc79c728e6a294ea5edd
#
#                                                   to    amount     timestamp  \
# 77056     0x336a3f0c4d40b1e39cee72e2e59330daf484848c  0.200000  1.524903e+09
# ...

# %%
phi_to_notphi = df[df['to'].isin(notphi_list['ID']) & df['from'].isin(isphi_list['ID'])]
phi_to_notphi
# Out:
#           Unnamed: 0                                        from  \
# 77059          77059  0x40949225c4a1745a9946f6aaf763241c082cb9ac
# 77060          77060  0x40949225c4a1745a9946f6aaf763241c082cb9ac
# 77061          77061  0x40949225c4a1745a9946f6aaf763241c082cb9ac
# 77062          77062  0x40949225c4a1745a9946f6aaf763241c082cb9ac
# 77063          77063  0x40949225c4a1745a9946f6aaf763241c082cb9ac
# ...              ...                                         ...
# 12388311    12388311  0x256b6711f4fab3c18df208f3eb7b87384fa13acd
# 12513236    12513236  0xfa3572b21b35cfe042ae940d5a74a9706882c6db
# 12559933    12559933  0xfbb62df5cbc8d0bc4c2a0e5c53b8602d49471495
# 12559934    12559934  0xfbb62df5cbc8d0bc4c2a0e5c53b8602d49471495
# 12559935    12559935  0xfbb62df5cbc8d0bc4c2a0e5c53b8602d49471495
#
#                                                   to    amount     timestamp  \
# 77059     0x84cd26c3ea544f9cbb1d2df5c195fcbb8975ceaf  0.100000  1.523194e+09
# ...

# %%
len(isphi_list) + len(notphi_list)
# Out:
# 29424

# %%
selected_columns1 = df[["from","fromIsPhi"]]
new_df1 = selected_columns1.copy()
selected_columns2 = df[["to","toIsPhi"]]
new_df2 = selected_columns2.copy()
new_df1.rename(columns = {'from':'ID', 'fromIsPhi':'IsPhi'}, inplace = True)
new_df2.rename(columns = {'to':'ID', 'toIsPhi':'IsPhi'}, inplace = True)
dataframe = [new_df1, new_df2]
allids = pd.concat(dataframe)
uniqueids1=allids.drop_duplicates()
uniqueids1
uniqueids1.IsPhi.value_counts()
# Out:
# 0    1623133
# 1       1153
# Name: IsPhi, dtype: int64

# %%
m=uniqueids1[~uniqueids1['ID'].isin(notphi_list['ID']) & ~uniqueids1['ID'].isin(isphi_list['ID'])]
m.shape
# Out:
# (1595140, 2)

# %%
non_phi_unrelated = m.sample(30000,random_state=69)
non_phi_unrelated
# Out:
#                                                   ID  IsPhi
# 5525241   0x623b074d184d5bcfb132ff430d57bafad0252f0f      0
# 1946341   0x935131da1be4cdf189244ae9eb946035c60a73f5      0
# 11913563  0x8b2b315077c52bed33d78f5f43ee1c66e88ce1b4      0
# 6354003   0x9ece057ea2e4e1643d17851d9b02c0a9e25f2908      0
# 12988503  0x8d23a34686f3dd0bcf81699c0dafb45f6b153c9b      0
# ...                                              ...    ...
# 837685    0x8dfc0e31a383efe9851a2a555ba316cdfefe002e      0
# 913974    0xc3821dd98ccc9e833e5b579b8399cf1c6a6fe0d4      0
# 4726733   0x359f2f69fadb1605fdc31c83b2722a6ccece2f15      0
# 3354720   0x1904d723b78bb44ee072e7dc36413221144361e9      0
# 8201714   0xf22aef491b8121e2c64c3e9c359904d25a883388      0
#
# [30000 rows x 2 columns]

# %%
import networkx as nx

# %%
related_to_unrelated_nonphi = df[df['to'].isin(non_phi_unrelated['ID']) | df['from'].isin(non_phi_unrelated['ID'])]
related_to_unrelated_nonphi
# Out:
#           Unnamed: 0                                        from  \
# 136              136  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# 181              181  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# 290              290  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# 291              291  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# 351              351  0x1f1e784a61a8ca0a90250bcd2170696655b28a21
# ...              ...                                         ...
# 13537546    13537546  0x2c02092f1a0213795ca52067e9c8de1b204994c2
# 13537547    13537547  0x2c02092f1a0213795ca52067e9c8de1b204994c2
# 13537560    13537560  0x5f1f1e17143a3870429026fe44791f0da740a07c
# 13546086    13546086  0x3e1af3c066120c9558ab806fab3eb069beaf2f03
# 13546179    13546179  0x5f7ad2cb33c049369e92361e5a4171219ecf1d74
#
#                                                   to     amount     timestamp  \
# 136       0x943ac7a3e7bf2eb927a2a443c05cfe75d7ce1a62   2.000000  1.498028e+09
# ...

# %%
selected_columns1 = related_to_unrelated_nonphi[["from","fromIsPhi"]]
new_df1 = selected_columns1.copy()
selected_columns2 = related_to_unrelated_nonphi[["to","toIsPhi"]]
new_df2 = selected_columns2.copy()
new_df1.rename(columns = {'from':'ID', 'fromIsPhi':'IsPhi'}, inplace = True)
new_df2.rename(columns = {'to':'ID', 'toIsPhi':'IsPhi'}, inplace = True)
dataframe = [new_df1, new_df2]
allids = pd.concat(dataframe)
uniqueids3=allids.drop_duplicates()
uniqueids3
uniqueids3.IsPhi.value_counts()
# Out:
# 0    43090
# Name: IsPhi, dtype: int64

# %%
sample = [related_to_unrelated_nonphi,phi_to_notphi,phi_to_phi,notphi_to_phi,notphi_to_notphi]
sample_df = pd.concat(sample)
sample_df.shape
# Out:
# (537063, 8)

# %%
selected_columns1 = sample_df[["from","fromIsPhi"]]
new_df1 = selected_columns1.copy()
selected_columns2 = sample_df[["to","toIsPhi"]]
new_df2 = selected_columns2.copy()
new_df1.rename(columns = {'from':'ID', 'fromIsPhi':'IsPhi'}, inplace = True)
new_df2.rename(columns = {'to':'ID', 'toIsPhi':'IsPhi'}, inplace = True)
dataframe = [new_df1, new_df2]
allids = pd.concat(dataframe)
uniqueids2=allids.drop_duplicates()
uniqueids2
uniqueids2.IsPhi.value_counts()
# Out:
# 0    65761
# 1     1153
# Name: IsPhi, dtype: int64

# %%
drive.mount('/gdrive')
with open('/gdrive/My Drive/bettersample.csv', 'w') as f:
  sample_df.to_csv(f)
# Out:
# Mounted at /gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
attributes = pd.read_csv("drive/My Drive/Account Attributes 3")
attributes
# Out:
#                                           account  avg_amount  avg_freq  \
# 0      0x0000038ce8229c981fad053b4783eea70fc12504    3.388000       2.0
# 1      0x000006e1cf569287a254698bacbce77c5b5a6151    8.548813       1.0
# 2      0x000155d2ddd2a897ff3a79e4c3089b97517530f5    1.000000       1.0
# 3      0x00019beb6f68d1268288b6a458a8fd90dd266455    0.008274       1.0
# 4      0x00020d45fc6f23a2d25c794fdc5af1a1fba151a4    1.500000       1.0
# ...                                           ...         ...       ...
# 42854  0xfffcc946fb6520a77a91c6c51f7938290945462f    0.010000       1.0
# 42855  0xfffce2b1d3fe38a5421763bcda947acb44d7957c   30.760000       1.0
# 42856  0xfffd0434d56bb35e8f3c7e337022cfbd370a240c    0.100000       1.0
# 42857  0xfffe195cd2623fc8cfc42280e2eee321195d841a   16.018950       1.0
# 42858  0xffffadf47d547e7a43327c2f551fdd7acc3d6048    0.500000       1.0
#
#        active_days
# 0                1
# 1                1
# 2                1
# 3                1
# ...

# %%
#making of the account graphs
import networkx as nx

# %%
G = nx.DiGraph()
count = 0
for user_id in attributes['account']:
  count+=1
  if count%100 == 0:
    print(count)
  user_attributes = attributes[attributes['account'] == user_id].set_index('account').squeeze()
  G.add_node(user_id, **user_attributes.to_dict())
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# ...

# %%
import pickle

# save graph object to file
pickle.dump(G, open('Transaction Graph.pickle', 'wb'))

# %%
count = 0
for _, transaction in sample_df.iterrows():
      count+=1
      if count%1000 == 0:
        print(count)
      source_node = transaction['from']
      target_node = transaction['to']
      amount = transaction['amount']
      timestamp = transaction['timestamp']
      if G.has_node(source_node) and G.has_node(target_node):
        # Add the directed edge with additional attribute 'timestamp'
        G.add_edge(source_node, target_node, weight=amount, timestamp=timestamp)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# ...

# %%
import pickle
drive.mount('/content/drive')

with open('Transaction Graph.pickle', 'wb') as f:
    pickle.dump(G, f)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import networkx as nx
# import pandas as pd

# # Assuming you have a master DiGraph 'G' and a DataFrame 'sample_df'
# # with columns 'from', 'to', 'amount', and 'timestamp'
# count = 0

# # Assuming 'attributes' is a DataFrame with columns 'account' and additional user attributes
# for user_id in attributes['account']:
#     count += 1
#     if count % 100 == 0:
#         print(count)

#     user_attributes = attributes[attributes['account'] == user_id].set_index('account').squeeze()
#     G.add_node(user_id, **user_attributes.to_dict())

# count = 0
# for _, transaction in sample_df.iterrows():
#     count += 1
#     if count % 1000 == 0:
#         print(count)

#     source_node = transaction['from']
#     target_node = transaction['to']
#     amount = transaction['amount']
#     timestamp = transaction['timestamp']

#     if G.has_node(source_node) and G.has_node(target_node):
#         G.add_edge(source_node, target_node, weight=amount, timestamp=timestamp)

# # Create subgraphs for each user
# user_subgraphs = {}
# count = 0
# for user_id in G.nodes():
#     count+=1
#     user_subgraph = G.subgraph(nx.ancestors(G, user_id) | {user_id})
#     user_subgraphs[user_id] = user_subgraph

# %%
pip install torch_geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 9.9 MB/s eta 0:00:00
# ...

# %%
# from google.colab import drive

# # Mount Google Drive
# drive.mount('/content/drive')

# %%
# !ls "drive/My Drive/"
# Out:
# 'Account Attributes'	    bettersample.csv	 'Transaction Graph.pickle'
# 'Account Attributes 2'	    bettersample.gsheet  'Truncated SVD'
# 'Account Attributes 3'	   'Colab Drive'	 'trying seige model.ipynb'
# 'Amount Matrix.ipynb'	   'Colab Notebooks'	  Untitled0.ipynb
# 'bettersample (1).gsheet'   sampled_data.csv	  Untitled1.ipynb

# %%
import torch
from torch_geometric.data import Data

# Create a NetworkX graph
nx_graph = G
# Add nodes and edges to nx_graph as needed

# Extract node features and edges from the NetworkX graph
num_nodes = nx_graph.number_of_nodes()
num_edges = nx_graph.number_of_edges()

# Assume you have node features in a dictionary, for example, 'node_feature'
node_features = torch.tensor([nx_graph.nodes[node]['node_feature'] for node in range(num_nodes)], dtype=torch.float32)

# Assume you have edge features in a dictionary, for example, 'edge_feature'
edge_index = torch.tensor(list(nx_graph.edges), dtype=torch.long).t().contiguous()

# Create the PyTorch Geometric Data object
data = Data(x=node_features, edge_index=edge_index)

# If there are additional attributes (e.g., edge weights), you can add them as follows:
# data.edge_attr = torch.tensor([nx_graph.edges[edge]['weight'] for edge in nx_graph.edges], dtype=torch.float32)

# Now 'data' contains your graph information in PyTorch Geometric format

# %%
def eval_node_classifier(model, graph, mask):

    model.eval()
    pred = model(graph).argmax(dim=1)
    correct = (pred[mask] == graph.y[mask]).sum()
    acc = int(correct) / int(mask.sum())

    return acc

# %%
def train_node_classifier(model, graph, optimizer, criterion, n_epochs=200):

    for epoch in range(1, n_epochs + 1):
        model.train()
        optimizer.zero_grad()
        out = model(graph)
        loss = criterion(out[graph.train_mask], graph.y[graph.train_mask])
        loss.backward()
        optimizer.step()

        pred = out.argmax(dim=1)
        acc = eval_node_classifier(model, graph, graph.val_mask)

        if epoch % 10 == 0:
            print(f'Epoch: {epoch:03d}, Train Loss: {loss:.3f}, Val Acc: {acc:.3f}')

    return model

# %%
from torch_geometric.nn import GCNConv
import torch.nn.functional as F

class GCN(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = GCNConv(3, 16)
        self.conv2 = GCNConv(16, 2)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        output = self.conv2(x, edge_index)

        return output

device = torch.device('cpu')
gcn = GCN().to(device)
optimizer_gcn = torch.optim.Adam(gcn.parameters(), lr=0.01, weight_decay=5e-4)
criterion = nn.CrossEntropyLoss()
gcn = train_node_classifier(gcn, graph, optimizer_gcn, criterion)

test_acc = eval_node_classifier(gcn, graph, graph.test_mask)
print(f'Test Acc: {test_acc:.3f}')
